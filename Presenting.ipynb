# %% [markdown]
# ## Numerical Integration

# %%
sales = { 'apple': 2, 'orange': 3, 'grapes': 4 }

element = sales.pop('apple', False)

# %%
element
# Out:
# 2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xs
# Out:
# array([0.])

# %% [markdown]
# Let $x = t - t^2$

# %%
t = np.linspace(-10,11,20)
plt.plot(t, -t**2+t)
